# %% [markdown]
# # Transforming
#
# This notebook is used to experiment with and create new features for the DiaRisk project. The goal is to engineer clinically relevant features that improve the predictive power of the model.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define file path for the raw data
RAW_DATA_PATH = "/Users/kartavyasoni/Documents/Projects/Data Science/DiaRisk---Readmission-Prediction/Data/Raw/diabetic_data.csv"

# Load the raw dataset
df = pd.read_csv(RAW_DATA_PATH)

# Check the shape of the dataset
print("\nDataset shape:", df.shape)

# Display the first few rows
df.head()
# Out:
# Dataset shape: (101766, 50)
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# Dataset shape
print("\nDataset shape:", df.shape)

# Columns with missing values
missing_values = df.isnull().sum()
print("\nMissing values in each column:\n", missing_values[missing_values > 0])

# Remove columns `max_glucose_serum` and `A1Cresult` as they have more than 50% missing values
df = df.drop(columns=['max_glu_serum', 'A1Cresult'])

print("\nDataset shape after removing columns with >50% missing values:", df.shape)
# Out:
# Dataset shape: (101766, 50)
#
# Missing values in each column:
#  max_glu_serum    96420
# A1Cresult        84748
# dtype: int64
#
# Dataset shape after removing columns with >50% missing values: (101766, 48)

# %%
# Normalized value counts for categorical features in percentage
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nValue count for {col} (Normalized):")
    print(df[col].value_counts(normalize=True) * 100)
# Out:
# Value count for race (Normalized):
# race
# Caucasian          74.778413
# AfricanAmerican    18.876639
# ?                   2.233555
# Hispanic            2.001651
# Other               1.479866
# Asian               0.629876
# Name: proportion, dtype: float64
#
# Value count for gender (Normalized):
# gender
# Female             53.758623
# Male               46.238429
# Unknown/Invalid     0.002948
# Name: proportion, dtype: float64
#
# Value count for age (Normalized):
# age
# [70-80)     25.615628
# [60-70)     22.092840
# [50-60)     16.956547
# [80-90)     16.898571
# [40-50)      9.516931
# [30-40)      3.709490
# [90-100)     2.744532
# [20-30)      1.628245
# [10-20)      0.679009
# [0-10)       0.158206
# Name: proportion, dtype: float64
#
# Value count for weight (Normalized):
# weight
# ?            96.858479
# [75-100)      1.312816
# [50-75)       0.881434
# [100-125)     0.614154
# [125-150)     0.142484
# [25-50)       0.095317
# [0-25)        0.047167
# [150-175)     0.034393
# [175-200)     0.010809
# >200          0.002948
# Name: proportion, dtype: float64
#
# Value count for payer_code (Normalized):
# payer_code
# ?     39.557416
# MC    31.876069
# HM     6.165124
# SP     4.920111
# BC     4.574219
# MD     3.470707
# CP     2.489043
# UN     2.405519
# CM     1.903386
# OG     1.015074
# PO     0.581727
# DM     0.539473
# CH     0.143466
# WC     0.132657
# OT     0.093351
# MP     0.077629
# SI     0.054046
# FR     0.000983
# Name: proportion, dtype: float64
#
# Value count for medical_specialty (Normalized):
# medical_specialty
# ?                                49.082208
# InternalMedicine                 14.381031
# Emergency/Trauma                  7.433720
# Family/GeneralPractice            7.310890
# Cardiology                        5.259124
#                                    ...
# SportsMedicine                    0.000983
# Speech                            0.000983
# Perinatology                      0.000983
# Neurophysiology                   0.000983
# Pediatrics-InfectiousDiseases     0.000983
# Name: proportion, Length: 73, dtype: float64
#
# Value count for diag_1 (Normalized):
# diag_1
# 428    6.742920
# 414    6.466796
# 786    3.946308
# 410    3.551284
# 486    3.447124
#          ...
# 373    0.000983
# 314    0.000983
# 684    0.000983
# 217    0.000983
# V51    0.000983
# Name: proportion, Length: 717, dtype: float64
#
# Value count for diag_2 (Normalized):
# diag_2
# 276     6.634829
# 428     6.546391
# 250     5.965647
# 427     4.948608
# 401     3.671167
#           ...
# E918    0.000983
# 46      0.000983
# V13     0.000983
# E850    0.000983
# 927     0.000983
# Name: proportion, Length: 749, dtype: float64
#
# Value count for diag_3 (Normalized):
# diag_3
# 250     11.354480
# 401      8.145157
# 276      5.085195
# 428      4.497573
# 427      3.886367
#           ...
# 657      0.000983
# 684      0.000983
# 603      0.000983
# E826     0.000983
# 971      0.000983
# Name: proportion, Length: 790, dtype: float64
#
# Value count for metformin (Normalized):
# metformin
# No        80.358862
# Steady    18.027632
# Up         1.048484
# Down       0.565022
# Name: proportion, dtype: float64
#
# Value count for repaglinide (Normalized):
# repaglinide
# No        98.487707
# Steady     1.359983
# Up         0.108091
# Down       0.044219
# Name: proportion, dtype: float64
#
# Value count for nateglinide (Normalized):
# nateglinide
# No        99.309200
# Steady     0.656408
# Up         0.023584
# Down       0.010809
# Name: proportion, dtype: float64
#
# Value count for chlorpropamide (Normalized):
# chlorpropamide
# No        99.915492
# Steady     0.077629
# Up         0.005896
# Down       0.000983
# Name: proportion, dtype: float64
#
# Value count for glimepiride (Normalized):
# glimepiride
# No        94.899082
# Steady     4.588959
# Up         0.321325
# Down       0.190633
# Name: proportion, dtype: float64
#
# Value count for acetohexamide (Normalized):
# acetohexamide
# No        99.999017
# Steady     0.000983
# Name: proportion, dtype: float64
#
# Value count for glipizide (Normalized):
# glipizide
# No        87.534147
# Steady    11.158933
# Up         0.756638
# Down       0.550282
# Name: proportion, dtype: float64
#
# Value count for glyburide (Normalized):
# glyburide
# No        89.534815
# Steady     9.113063
# Up         0.797909
# Down       0.554213
# Name: proportion, dtype: float64
#
# Value count for tolbutamide (Normalized):
# tolbutamide
# No        99.977399
# Steady     0.022601
# Name: proportion, dtype: float64
#
# Value count for pioglitazone (Normalized):
# pioglitazone
# No        92.799167
# Steady     6.854942
# Up         0.229939
# Down       0.115952
# Name: proportion, dtype: float64
#
# Value count for rosiglitazone (Normalized):
# rosiglitazone
# No        93.745455
# Steady     5.994143
# Up         0.174911
# Down       0.085490
# Name: proportion, dtype: float64
#
# Value count for acarbose (Normalized):
# acarbose
# No        99.697345
# Steady     0.289881
# Up         0.009826
# Down       0.002948
# Name: proportion, dtype: float64
#
# Value count for miglitol (Normalized):
# miglitol
# No        99.962659
# Steady     0.030462
# Down       0.004913
# Up         0.001965
# Name: proportion, dtype: float64
#
# Value count for troglitazone (Normalized):
# troglitazone
# No        99.997052
# Steady     0.002948
# Name: proportion, dtype: float64
#
# Value count for tolazamide (Normalized):
# tolazamide
# No        99.961677
# Steady     0.037341
# Up         0.000983
# Name: proportion, dtype: float64
#
# Value count for examide (Normalized):
# examide
# No    100.0
# Name: proportion, dtype: float64
#
# Value count for citoglipton (Normalized):
# citoglipton
# No    100.0
# Name: proportion, dtype: float64
#
# Value count for insulin (Normalized):
# insulin
# No        46.560737
# Steady    30.313661
# Down      12.005974
# Up        11.119627
# Name: proportion, dtype: float64
#
# Value count for glyburide-metformin (Normalized):
# glyburide-metformin
# No        99.306252
# Steady     0.679991
# Up         0.007861
# Down       0.005896
# Name: proportion, dtype: float64
#
# Value count for glipizide-metformin (Normalized):
# glipizide-metformin
# No        99.987226
# Steady     0.012774
# Name: proportion, dtype: float64
#
# Value count for glimepiride-pioglitazone (Normalized):
# glimepiride-pioglitazone
# No        99.999017
# Steady     0.000983
# Name: proportion, dtype: float64
#
# Value count for metformin-rosiglitazone (Normalized):
# metformin-rosiglitazone
# No        99.998035
# Steady     0.001965
# Name: proportion, dtype: float64
#
# Value count for metformin-pioglitazone (Normalized):
# metformin-pioglitazone
# No        99.999017
# Steady     0.000983
# Name: proportion, dtype: float64
#
# Value count for change (Normalized):
# change
# No    53.804807
# Ch    46.195193
# Name: proportion, dtype: float64
#
# Value count for diabetesMed (Normalized):
# diabetesMed
# Yes    77.003125
# No     22.996875
# Name: proportion, dtype: float64
#
# Value count for readmitted (Normalized):
# readmitted
# NO     53.911916
# >30    34.928169
# <30    11.159916
# Name: proportion, dtype: float64

# %%
# Remove columns that have very high missining values as placeholders and are not useful for analysis
columns_to_remove = ['weight', 'payer_code']
df = df.drop(columns=columns_to_remove, errors='ignore')

print("\nDataset shape after removing unnecessary columns:", df.shape)
# Out:
# Dataset shape after removing unnecessary columns: (101766, 46)

# %%
# Replace placeholders in 'medical_specialty' with 'Missing' for better clarity
df['medical_specialty'] = df['medical_specialty'].replace('?', 'Missing')

# Remove rows with placeholders indicating missing data.
placeholders = ['?', 'Unknown/Invalid']
df = df.replace(placeholders, np.nan).dropna()

print("\nDataset shape after removing rows with placeholders for missing data:", df.shape)
# Out:
# Dataset shape after removing rows with placeholders for missing data: (98052, 46)

# %%
# calculate unique values for patient_nbr
unique_patients = df['patient_nbr'].nunique()
print(f"\nNumber of unique patients: {unique_patients}")

# Keep only the first occurrence of each patient for bias reduction
df = df.drop_duplicates(subset='patient_nbr', keep='first')

print(f"\nDataset shape after keeping only the first occurrence of each patient: {df.shape}")
# Out:
# Number of unique patients: 68629
#
# Dataset shape after keeping only the first occurrence of each patient: (68629, 46)

# %%
# Normalized value counts for categorical features in percentage
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nValue counts for {col} (normalized):")
    print(df[col].value_counts(normalize=True) * 100)
# Out:
# Value counts for race (normalized):
# race
# Caucasian          76.996605
# AfricanAmerican    18.454298
# Hispanic            2.152151
# Other               1.690248
# Asian               0.706698
# Name: proportion, dtype: float64
#
# Value counts for gender (normalized):
# gender
# Female    53.303997
# Male      46.696003
# Name: proportion, dtype: float64
#
# Value counts for age (normalized):
# age
# [70-80)     25.706334
# [60-70)     22.459893
# [50-60)     17.483863
# [80-90)     16.388116
# [40-50)      9.514928
# [30-40)      3.680660
# [90-100)     2.682539
# [20-30)      1.470224
# [10-20)      0.520188
# [0-10)       0.093255
# Name: proportion, dtype: float64
#
# Value counts for medical_specialty (normalized):
# medical_specialty
# Missing                   48.427050
# InternalMedicine          15.130630
# Family/GeneralPractice     7.134010
# Emergency/Trauma           6.409827
# Cardiology                 6.065949
#                             ...
# SportsMedicine             0.001457
# Dermatology                0.001457
# Proctology                 0.001457
# Psychiatry-Addictive       0.001457
# Resident                   0.001457
# Name: proportion, Length: 71, dtype: float64
#
# Value counts for diag_1 (normalized):
# diag_1
# 414    7.383176
# 428    5.659415
# 786    4.275161
# 410    4.097393
# 486    3.457722
#          ...
# 385    0.001457
# 347    0.001457
# 334    0.001457
# 143    0.001457
# V51    0.001457
# Name: proportion, Length: 692, dtype: float64
#
# Value counts for diag_2 (normalized):
# diag_2
# 276     6.446254
# 250     6.443340
# 428     6.162118
# 427     5.034315
# 401     4.345102
#           ...
# 171     0.001457
# V13     0.001457
# E850    0.001457
# 800     0.001457
# 927     0.001457
# Name: proportion, Length: 716, dtype: float64
#
# Value counts for diag_3 (normalized):
# diag_3
# 250     12.796340
# 401      9.361932
# 276      4.960002
# 428      4.071165
# 427      3.854056
#           ...
# E882     0.001457
# E822     0.001457
# 395      0.001457
# 754      0.001457
# 971      0.001457
# Name: proportion, Length: 756, dtype: float64
#
# Value counts for metformin (normalized):
# metformin
# No        79.052587
# Steady    19.188681
# Up         1.155488
# Down       0.603244
# Name: proportion, dtype: float64
#
# Value counts for repaglinide (normalized):
# repaglinide
# No        98.669659
# Steady     1.186088
# Up         0.101998
# Down       0.042256
# Name: proportion, dtype: float64
#
# Value counts for nateglinide (normalized):
# nateglinide
# No        99.287473
# Steady     0.677556
# Up         0.023314
# Down       0.011657
# Name: proportion, dtype: float64
#
# Value counts for chlorpropamide (normalized):
# chlorpropamide
# No        99.899459
# Steady     0.093255
# Up         0.005828
# Down       0.001457
# Name: proportion, dtype: float64
#
# Value counts for glimepiride (normalized):
# glimepiride
# No        94.771889
# Steady     4.705008
# Up         0.329307
# Down       0.193796
# Name: proportion, dtype: float64
#
# Value counts for acetohexamide (normalized):
# acetohexamide
# No        99.998543
# Steady     0.001457
# Name: proportion, dtype: float64
#
# Value counts for glipizide (normalized):
# glipizide
# No        87.189089
# Steady    11.455799
# Up         0.824724
# Down       0.530388
# Name: proportion, dtype: float64
#
# Value counts for glyburide (normalized):
# glyburide
# No        89.013391
# Steady     9.520757
# Up         0.880094
# Down       0.585758
# Name: proportion, dtype: float64
#
# Value counts for tolbutamide (normalized):
# tolbutamide
# No        99.973772
# Steady     0.026228
# Name: proportion, dtype: float64
#
# Value counts for pioglitazone (normalized):
# pioglitazone
# No        92.533769
# Steady     7.097583
# Up         0.253537
# Down       0.115112
# Name: proportion, dtype: float64
#
# Value counts for rosiglitazone (normalized):
# rosiglitazone
# No        93.377435
# Steady     6.323857
# Up         0.193796
# Down       0.104912
# Name: proportion, dtype: float64
#
# Value counts for acarbose (normalized):
# acarbose
# No        99.715864
# Steady     0.269565
# Up         0.014571
# Name: proportion, dtype: float64
#
# Value counts for miglitol (normalized):
# miglitol
# No        99.970858
# Steady     0.026228
# Down       0.001457
# Up         0.001457
# Name: proportion, dtype: float64
#
# Value counts for troglitazone (normalized):
# troglitazone
# No        99.995629
# Steady     0.004371
# Name: proportion, dtype: float64
#
# Value counts for tolazamide (normalized):
# tolazamide
# No        99.959201
# Steady     0.040799
# Name: proportion, dtype: float64
#
# Value counts for examide (normalized):
# examide
# No    100.0
# Name: proportion, dtype: float64
#
# Value counts for citoglipton (normalized):
# citoglipton
# No    100.0
# Name: proportion, dtype: float64
#
# Value counts for insulin (normalized):
# insulin
# No        49.177461
# Steady    30.557053
# Down      10.549476
# Up         9.716009
# Name: proportion, dtype: float64
#
# Value counts for glyburide-metformin (normalized):
# glyburide-metformin
# No        99.307873
# Steady     0.679013
# Up         0.008743
# Down       0.004371
# Name: proportion, dtype: float64
#
# Value counts for glipizide-metformin (normalized):
# glipizide-metformin
# No        99.9898
# Steady     0.0102
# Name: proportion, dtype: float64
#
# Value counts for glimepiride-pioglitazone (normalized):
# glimepiride-pioglitazone
# No    100.0
# Name: proportion, dtype: float64
#
# Value counts for metformin-rosiglitazone (normalized):
# metformin-rosiglitazone
# No    100.0
# Name: proportion, dtype: float64
#
# Value counts for metformin-pioglitazone (normalized):
# metformin-pioglitazone
# No        99.998543
# Steady     0.001457
# Name: proportion, dtype: float64
#
# Value counts for change (normalized):
# change
# No    55.257981
# Ch    44.742019
# Name: proportion, dtype: float64
#
# Value counts for diabetesMed (normalized):
# diabetesMed
# Yes    75.772633
# No     24.227367
# Name: proportion, dtype: float64
#
# Value counts for readmitted (normalized):
# readmitted
# NO     59.565198
# >30    31.508546
# <30     8.926256
# Name: proportion, dtype: float64

# %% [markdown]
# ## Data Typing (Casting)

# %%
# In column `race` keep 'Caucasian', 'AfricanAmerican' and replace others with 'Other'
df['race'] = df['race'].apply(lambda x: x if x in ['Caucasian', 'AfricanAmerican'] else 'Other')
print("\nValue counts for race after grouping others:\n", df['race'].value_counts(normalize=True) * 100)
# Out:
# Value counts for race after grouping others:
#  race
# Caucasian          76.996605
# AfricanAmerican    18.454298
# Other               4.549097
# Name: proportion, dtype: float64

# %%
# In the `age` column, group ages into broader categories
age_bins = [0, 50, 70, 120]
age_labels = ['<50', '50-70', '>70']

# Extract the lower bound of the age range and convert it to integers
df['age'] = df['age'].str.extract(r'(\d+)-')[0].astype(int)

# Group ages into broader categories
df['age'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)

print("\nValue counts for age after grouping:\n", df['age'].value_counts(normalize=True) * 100)
# Out:
# Value counts for age after grouping:
#  age
# >70      44.776989
# 50-70    39.943756
# <50      15.279255
# Name: proportion, dtype: float64

# %%
# In column `medical_specialty`, group less frequent specialties into 'Other'
specialty_counts = df['medical_specialty'].value_counts(normalize=True)
less_frequent_specialties = specialty_counts[specialty_counts < 0.05].index
df['medical_specialty'] = df['medical_specialty'].replace(less_frequent_specialties, 'Other')

print("\nValue counts for medical_specialty after grouping less frequent specialties:\n", df['medical_specialty'].value_counts(normalize=True) * 100)
# Out:
# Value counts for medical_specialty after grouping less frequent specialties:
#  medical_specialty
# Missing                   48.427050
# Other                     16.832534
# InternalMedicine          15.130630
# Family/GeneralPractice     7.134010
# Emergency/Trauma           6.409827
# Cardiology                 6.065949
# Name: proportion, dtype: float64

# %%
# Group diag_1, diag_2, diag_3 into broader categories based on ICD-9 chapters

# Define a dictionary for ICD-9 chapter ranges
icd9_chapters = {
    'Infectious and Parasitic Diseases': (1, 140),
    'Neoplasms': (140, 240),
    'Endocrine, Nutritional, and Metabolic Diseases': (240, 280),
    'Blood and Blood-Forming Organs': (280, 290),
    'Mental Disorders': (290, 320),
    'Nervous System': (320, 390),
    'Circulatory System': (390, 460),
    'Respiratory System': (460, 520),
    'Digestive System': (520, 580),
    'Genitourinary System': (580, 630),
    'Pregnancy, Childbirth, and the Puerperium': (630, 680),
    'Skin and Subcutaneous Tissue': (680, 710),
    'Musculoskeletal System': (710, 740),
    'Congenital Anomalies': (740, 760),
    'Perinatal Conditions': (760, 780),
    'Symptoms, Signs, and Ill-Defined Conditions': (780, 800),
    'Injury and Poisoning': (800, 1000)
}

# Define a function to map diagnosis codes to broader categories
def map_to_icd9_chapter(code):
    try:
        code = float(code)
        for chapter, (start, end) in icd9_chapters.items():
            if start <= code < end:
                return chapter
        return 'Other'
    except ValueError:
        return 'Other'

# Apply the mapping function to diag_1, diag_2, diag_3
diag_columns = ['diag_1', 'diag_2', 'diag_3']
for col in diag_columns:
    df[col] = df[col].apply(map_to_icd9_chapter)

# Display the value counts for the grouped categories
for col in diag_columns:
    print(f"\nValue counts for {col} after grouping:")
    print(df[col].value_counts(normalize=True) * 100)
# Out:
# Value counts for diag_1 after grouping:
# diag_1
# Circulatory System                                30.865960
# Endocrine, Nutritional, and Metabolic Diseases    10.173542
# Respiratory System                                 9.500357
# Digestive System                                   8.999111
# Symptoms, Signs, and Ill-Defined Conditions        7.799910
# Injury and Poisoning                               6.648793
# Musculoskeletal System                             5.665244
# Genitourinary System                               4.942517
# Neoplasms                                          3.842399
# Infectious and Parasitic Diseases                  2.570342
# Skin and Subcutaneous Tissue                       2.504772
# Mental Disorders                                   2.124466
# Other                                              1.312856
# Nervous System                                     1.237086
# Blood and Blood-Forming Organs                     0.939836
# Pregnancy, Childbirth, and the Puerperium          0.814524
# Congenital Anomalies                               0.058284
# Name: proportion, dtype: float64
#
# Value counts for diag_2 after grouping:
# diag_2
# Circulatory System                                31.502718
# Endocrine, Nutritional, and Metabolic Diseases    21.091667
# Respiratory System                                 9.611097
# Genitourinary System                               7.387548
# Symptoms, Signs, and Ill-Defined Conditions        4.576782
# Digestive System                                   3.896312
# Skin and Subcutaneous Tissue                       3.153186
# Blood and Blood-Forming Organs                     2.994361
# Mental Disorders                                   2.592199
# Injury and Poisoning                               2.589284
# Other                                              2.541200
# Neoplasms                                          2.493115
# Musculoskeletal System                             1.830130
# Infectious and Parasitic Diseases                  1.811188
# Nervous System                                     1.304113
# Pregnancy, Childbirth, and the Puerperium          0.511446
# Congenital Anomalies                               0.113655
# Name: proportion, dtype: float64
#
# Value counts for diag_3 after grouping:
# diag_3
# Circulatory System                                29.930496
# Endocrine, Nutritional, and Metabolic Diseases    27.361611
# Respiratory System                                 6.355914
# Genitourinary System                               5.595302
# Other                                              5.073657
# Symptoms, Signs, and Ill-Defined Conditions        4.463128
# Digestive System                                   3.546606
# Mental Disorders                                   3.071588
# Blood and Blood-Forming Organs                     2.514972
# Skin and Subcutaneous Tissue                       2.197322
# Injury and Poisoning                               2.035583
# Musculoskeletal System                             1.948156
# Neoplasms                                          1.814102
# Nervous System                                     1.798074
# Infectious and Parasitic Diseases                  1.796617
# Pregnancy, Childbirth, and the Puerperium          0.391963
# Congenital Anomalies                               0.104912
# Name: proportion, dtype: float64

# %%
# Keep only the primary diagnosis for analysis and update column name
df['primiary_diagnosis'] = df['diag_1']
df = df.drop(columns=['diag_1','diag_2','diag_3'])

# Remove rows where primary diagnosis is 'Other'
df = df[df['primiary_diagnosis'] != 'Other']

print("\nDataset shape after dropping diag_2, diag_3 and removing 'Other' from primary diagnosis:", df.shape)
# Out:
# Dataset shape after dropping diag_2, diag_3 and removing 'Other' from primary diagnosis: (67728, 44)

# %%
# Remove column with only one value having a distribution higher than 98%
columns_to_check = df.columns
for col in columns_to_check:
    if df[col].value_counts(normalize=True).iloc[0] > 0.98:
        df = df.drop(columns=[col])

print("\nDataset shape after removing columns with high distribution:", df.shape)
# Out:
# Dataset shape after removing columns with high distribution: (67728, 28)

# %%
# Update all columns with values 'Up' and 'Down' into 'Changed'
for col in df.dtypes[df.dtypes == 'object'].index:
    df[col] = df[col].replace({'Up': 'Changed', 'Down': 'Changed'})

print("\nDataset shape after feature engineering:", df.shape)
# Out:
# Dataset shape after feature engineering: (67728, 28)
